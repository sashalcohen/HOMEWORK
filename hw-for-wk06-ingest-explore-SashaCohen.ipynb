# %% [markdown]
# # Homework for Week 3
#
# The goal for this homework is to see the relevant journalistic uses for what we learned in class in week 2.
#
# 1. access specific data within a dataset,
# 2. break down larger datasets into smaller chunks (subset),
# 3. Ingest different types of spreadsheets into Pandas,
# 4. Gather general info about our dataframes

# %% [markdown]
# # List Slicing
# ## Natural disasters list
#
# The Small Business Administration has a list of natural disasters that cause extensive economic damage. Run the next cell to pull the list into memory

# %%
disasters = [
        "Landslides",
        "Earthquake",
        "Wildfires",
        "Tornadoes",
        "Hurricane",
        "Wind Storm",
        "Winter Freeze",
        "Ice Storm",
        "Drought",
        "Tsunami",
        "Flash floods",
        "Mudslides",
        "Torrential rainfall",
        "Riverine floods",
        "Tidal Surge"
         ]

# %%
## call the disaster list here
disasters
# Out:
# ['Landslides',
#  'Earthquake',
#  'Wildfires',
#  'Tornadoes',
#  'Hurricane',
#  'Wind Storm',
#  'Winter Freeze',
#  'Ice Storm',
#  'Drought',
#  'Tsunami',
#  'Flash floods',
#  'Mudslides',
#  'Torrential rainfall',
#  'Riverine floods',
#  'Tidal Surge']

# %%
## the first item in the list
disasters[0]
# Out:
# 'Landslides'

# %%
## call the penultimate item (without manually counting the number of items)
disasters[-2]
# Out:
# 'Riverine floods'

# %% [markdown]
# ### Clarification:
#
# For the next two questions, I am referring to numerical positions rather than zero-indexed positions. In other words, you will have to translate the numerical position into zero-indexed positions in your slicing.

# %%
## create a new list called disasters_subset that holds the 3rd to 6th items inclusive
disasters_subset = disasters[2:6]
disasters_subset
# Out:
# ['Wildfires', 'Tornadoes', 'Hurricane', 'Wind Storm']

# %%
## create a new list called disasters_subset2 that holds the 2nd through 8th items
disasters_subset2 = disasters[1:8]

# %% [markdown]
# ## Pandas - Importing data
#
# Please download from Google Drive the following data and then upload it into this notebook:
#
# - <a href="https://drive.google.com/file/d/1izg0nXFm8vBJAhz77LFdSMQGP4STvpEk/view?usp=sharing">EMS excerpt</a>,
#
# - <a href="https://docs.google.com/spreadsheets/d/1sUEttreon8IKzCmsfRQ6cPA1lfeuNDu9/edit?usp=sharing&ouid=107646296031550187966&rtpof=true&sd=true">Customs, Border Patrol</a>
#
# **Give yourself time to download it. Some of the files are large!**

# %%
## import the pandas library in this cell

import pandas as pd

# %% [markdown]
# ### Ingest the following dataset into this note:
#
# - ```ems20_1st_6months_excerpt.csv``` into a dataframe named ```ems2020_excerpt_df```

# %%
## import data and store in dataframe

ems2020_excerpt_df = pd.read_csv("ems20_1st_6months_excerpt.csv")

# %%
## call the first 10 rows
ems2020_excerpt_df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
# 7        201471743  2020-05-26 12:45:46            INJURY
# 8        201180116  2020-04-27 00:57:48               EDP
# 9        200572739  2020-02-26 15:15:25            CARDBR
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# 3                            4            DRUG                          4
# 4                            4            DRUG                          4
# 5                            4            DRUG                          4
# 6                            2             UNC                          2
# 7                            5          INJURY                          5
# 8                            7            EDPC                          7
# 9                            2          CARDBR                          2
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    04/19/2020 10:26:24 AM                              Y
# 1    02/11/2020 07:25:56 PM                              Y
# 2    02/12/2020 09:37:24 PM                              Y
# 3    06/09/2020 12:52:44 AM                              Y
# 4    01/03/2020 08:44:11 PM                              Y
# 5    02/22/2020 01:27:21 AM                              Y
# 6    02/23/2020 07:08:44 PM                              Y
# 7    05/26/2020 12:46:04 PM                              Y
# 8    04/27/2020 12:58:07 AM                              Y
# 9    02/26/2020 03:16:35 PM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    04/19/2020 10:26:24 AM  ...           40.0
# 1                             9    02/11/2020 07:26:09 PM  ...           52.0
# 2                            32    02/12/2020 09:38:27 PM  ...          106.0
# 3                            14    06/09/2020 12:52:59 AM  ...           19.0
# 4                             6    01/03/2020 08:44:17 PM  ...           66.0
# 5                            63    02/22/2020 01:27:41 AM  ...           25.0
# 6                            17    02/23/2020 07:09:16 PM  ...           44.0
# 7                            18    05/26/2020 12:46:15 PM  ...           41.0
# 8                            19    04/27/2020 12:58:15 AM  ...           50.0
# 9                            70    02/26/2020 03:16:49 PM  ...          106.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 8.0              201.0                      7.0
# 1                14.0              207.0                     10.0
# 2                32.0              410.0                     27.0
# 3                 4.0              108.0                      2.0
# 4                39.0              312.0                     15.0
# 5                 8.0              111.0                      4.0
# 6                 8.0              204.0                      9.0
# 7                17.0              202.0                      8.0
# 8                11.0              208.0                     10.0
# 9                28.0              410.0                     27.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  15.0                N                       N
# 1                  15.0                N                       N
# 2                   8.0                N                       N
# 3                  12.0                N                       N
# 4                   7.0                N                       N
# 5                  12.0                N                       N
# 6                  15.0                N                       N
# 7                  15.0                N                       N
# 8                  16.0                N                       N
# 9                   5.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N  chunk170.csv
# 1                 N                   N  chunk166.csv
# 2                 N                   N  chunk166.csv
# 3                 N                   N  chunk171.csv
# 4                 N                   N  chunk165.csv
# 5                 N                   N  chunk167.csv
# 6                 N                   N  chunk167.csv
# 7                 N                   N  chunk171.csv
# 8                 N                   N  chunk170.csv
# 9                 N                   N  chunk167.csv
#
# [10 rows x 32 columns]

# %%
## call the last 5 rows
ems2020_excerpt_df.tail()
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# 13116                            2          DIFFFC                          2
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 13112    02/08/2020 07:52:34 PM                              Y
# 13113    01/03/2020 10:51:39 PM                              Y
# 13114    02/11/2020 09:52:09 PM                              Y
# 13115    06/22/2020 03:58:07 PM                              Y
# 13116    03/26/2020 07:33:50 PM                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 13112                           181    02/08/2020 07:53:00 PM  ...
# 13113                             6    01/03/2020 10:52:21 PM  ...
# 13114                            60    02/11/2020 09:52:18 PM  ...
# 13115                            23    06/22/2020 03:58:19 PM  ...
# 13116                            31    03/26/2020 07:34:08 PM  ...
#
#       POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 13112           72.0                38.0              307.0
# 13113           75.0                42.0              305.0
# 13114           48.0                15.0              206.0
# 13115           62.0                47.0              311.0
# 13116          103.0                27.0              412.0
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 13112                     15.0                   7.0                N
# 13113                     19.0                   8.0                N
# 13114                     10.0                  15.0                N
# 13115                     21.0                  11.0                N
# 13116                     29.0                   5.0                N
#
#       SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 13112                       N                 N                   N
# 13113                       N                 N                   N
# 13114                       N                 N                   N
# 13115                       N                 N                   N
# 13116                       N                 N                   N
#
#              source
# 13112  chunk166.csv
# 13113  chunk165.csv
# 13114  chunk166.csv
# 13115  chunk172.csv
# 13116  chunk168.csv
#
# [5 rows x 32 columns]

# %%
## call a 20 random rows
ems2020_excerpt_df.sample(20)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 7861         201623817  2020-06-10 23:00:10            INJURY
# 3823         200430632  2020-02-12 06:29:51              SICK
# 6839         200831633  2020-03-23 09:59:18               UNC
# 5014         201193425  2020-04-28 21:43:21            DIFFBR
# 10780        200680102  2020-03-08 00:34:29              SICK
# 2713         200784084  2020-03-18 20:14:02               UNC
# 4506         200021151  2020-01-02 08:40:19             ABDPN
# 10048        201331706  2020-05-12 13:38:46             ABDPN
# 3842         200821675  2020-03-22 10:28:56              SICK
# 2928         201640753  2020-06-12 07:21:57            UNKNOW
# 5220         200103084  2020-01-10 16:22:12            SICMIN
# 136          201721991  2020-06-20 13:54:26              DRUG
# 2879         201522211  2020-05-31 15:14:08            UNKNOW
# 4463         200601494  2020-02-29 10:21:51            UNKNOW
# 3382         200501600  2020-02-19 11:34:37            CARDBR
# 4580         201391053  2020-05-18 09:32:39             ABDPN
# 3993         200154712  2020-01-15 22:36:43            DIFFBR
# 1713         200774180  2020-03-17 21:03:18            SICMIN
# 10485        200561890  2020-02-25 12:22:20             OBMAJ
# 9079         201681189  2020-06-16 10:35:47            RESPIR
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 7861                             5          INJMAJ                          3
# 3823                             6            SICK                          6
# 6839                             2            SICK                          6
# 5014                             2          DIFFBR                          2
# 10780                            6            SICK                          6
# 2713                             2             UNC                          2
# 4506                             5           ABDPN                          5
# 10048                            5           ABDPN                          5
# 3842                             6            SICK                          6
# 2928                             4          UNKNOW                          4
# 5220                             7          SICMIN                          7
# 136                              4            DRUG                          4
# 2879                             4          UNKNOW                          4
# 4463                             4          INJMAJ                          3
# 3382                             2          CARDBR                          2
# 4580                             5           ABDPN                          5
# 3993                             2            SICK                          6
# 1713                             7          SICMIN                          7
# 10485                            3            CARD                          3
# 9079                             4          RESPIR                          4
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 7861     06/10/2020 11:00:45 PM                              Y
# 3823     02/12/2020 06:30:17 AM                              Y
# 6839     03/23/2020 10:00:18 AM                              Y
# 5014     04/28/2020 09:43:40 PM                              Y
# 10780    03/08/2020 12:34:39 AM                              Y
# 2713     03/18/2020 08:14:39 PM                              Y
# 4506     01/02/2020 08:40:37 AM                              Y
# 10048    05/12/2020 01:39:09 PM                              Y
# 3842     03/22/2020 10:33:34 AM                              Y
# 2928     06/12/2020 07:22:03 AM                              Y
# 5220     01/10/2020 04:37:31 PM                              Y
# 136      06/20/2020 01:55:02 PM                              Y
# 2879     05/31/2020 03:14:14 PM                              Y
# 4463     02/29/2020 10:22:07 AM                              Y
# 3382     02/19/2020 11:35:16 AM                              Y
# 4580     05/18/2020 09:32:50 AM                              Y
# 3993     01/15/2020 10:37:27 PM                              Y
# 1713     03/17/2020 09:03:51 PM                              Y
# 10485    02/25/2020 12:23:10 PM                              Y
# 9079     06/16/2020 10:36:00 AM                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 7861                             35    06/10/2020 11:00:56 PM  ...
# 3823                             26    02/12/2020 06:30:37 AM  ...
# 6839                             60    03/23/2020 10:00:36 AM  ...
# 5014                             19    04/28/2020 09:44:00 PM  ...
# 10780                            10    03/08/2020 12:34:55 AM  ...
# 2713                             37    03/18/2020 08:15:10 PM  ...
# 4506                             18    01/02/2020 08:40:47 AM  ...
# 10048                            23    05/12/2020 01:40:12 PM  ...
# 3842                            278    03/22/2020 10:33:51 AM  ...
# 2928                              6    06/12/2020 07:22:13 AM  ...
# 5220                            919    01/10/2020 04:37:43 PM  ...
# 136                              36    06/20/2020 01:55:09 PM  ...
# 2879                              6    05/31/2020 03:14:29 PM  ...
# 4463                             16    02/29/2020 10:22:28 AM  ...
# 3382                             39    02/19/2020 11:35:24 AM  ...
# 4580                             11    05/18/2020 09:33:00 AM  ...
# 3993                             44    01/15/2020 10:38:07 PM  ...
# 1713                             33    03/17/2020 09:04:08 PM  ...
# 10485                            50    02/25/2020 12:23:58 PM  ...
# 9079                             13    06/16/2020 10:36:14 AM  ...
#
#       POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 7861            42.0                17.0              203.0
# 3823           113.0                28.0              412.0
# 6839           114.0                22.0              401.0
# 5014            23.0                 8.0              111.0
# 10780           61.0                46.0              315.0
# 2713           101.0                31.0              414.0
# 4506            14.0                 3.0              104.0
# 10048           52.0                15.0              207.0
# 3842            40.0                 8.0              201.0
# 2928            17.0                 4.0              106.0
# 5220            60.0                43.0              313.0
# 136             33.0                10.0              112.0
# 2879            83.0                34.0              304.0
# 4463            42.0                17.0              203.0
# 3382            19.0                 5.0              108.0
# 4580           105.0                23.0              413.0
# 3993            43.0                18.0              209.0
# 1713            70.0                45.0              314.0
# 10485          114.0                22.0              401.0
# 9079            71.0                40.0              309.0
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 7861                       9.0                  15.0                N
# 3823                      28.0                   5.0                N
# 6839                      30.0                  12.0                N
# 5014                       4.0                  13.0                N
# 10780                     22.0                   9.0                N
# 2713                      27.0                   5.0                N
# 4506                       2.0                  10.0                N
# 10048                     10.0                  13.0                N
# 3842                       7.0                  15.0                N
# 2928                       2.0                  12.0                N
# 5220                      21.0                  11.0                N
# 136                        6.0                  13.0                N
# 2879                      32.0                   8.0                N
# 4463                      12.0                  15.0                N
# 3382                       2.0                  12.0                N
# 4580                      29.0                   5.0                N
# 3993                       8.0                  15.0                N
# 1713                      22.0                   9.0                N
# 10485                     30.0                  14.0                N
# 9079                      17.0                   9.0                N
#
#       SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 7861                        N                 N                   N
# 3823                        N                 N                   N
# 6839                        N                 N                   N
# 5014                        N                 N                   N
# 10780                       N                 N                   N
# 2713                        N                 N                   N
# 4506                        N                 N                   N
# 10048                       N                 N                   N
# 3842                        N                 N                   N
# 2928                        N                 N                   N
# 5220                        N                 N                   N
# 136                         N                 N                   N
# 2879                        N                 N                   N
# 4463                        N                 N                   N
# 3382                        N                 N                   N
# 4580                        N                 N                   N
# 3993                        N                 N                   N
# 1713                        N                 N                   N
# 10485                       N                 N                   N
# 9079                        N                 N                   N
#
#              source
# 7861   chunk171.csv
# 3823   chunk166.csv
# 6839   chunk168.csv
# 5014   chunk170.csv
# 10780  chunk167.csv
# 2713   chunk168.csv
# 4506   chunk165.csv
# 10048  chunk170.csv
# 3842   chunk168.csv
# 2928   chunk171.csv
# 5220   chunk165.csv
# 136    chunk172.csv
# 2879   chunk171.csv
# 4463   chunk167.csv
# 3382   chunk167.csv
# 4580   chunk171.csv
# 3993   chunk165.csv
# 1713   chunk168.csv
# 10485  chunk167.csv
# 9079   chunk172.csv
#
# [20 rows x 32 columns]

# %%
## how might you slice this df to show only rows 42 through 51 inclusive
ems2020_excerpt_df.loc[42:51]
# Out:
#     CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 42        201542166  2020-06-02 14:39:16              CVAC
# 43        201290003  2020-05-08 00:02:09               EDP
# 44        201034249  2020-04-12 21:17:40              SICK
# 45        201784219  2020-06-26 22:59:45            INJURY
# 46        201001249  2020-04-09 08:29:26            INJURY
# 47        200880324  2020-03-28 01:22:22              SICK
# 48        201323660  2020-05-11 23:40:32               UNC
# 49        201632450  2020-06-11 16:18:15            TRAUMA
# 50        200630307  2020-03-03 02:35:05              SICK
# 51        200314692  2020-01-31 22:35:56            STATEP
#
#     INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 42                            2            CVAC                          2
# 43                            7             EDP                          7
# 44                            6            SICK                          6
# 45                            5          INJURY                          5
# 46                            5          INJURY                          5
# 47                            6            SICK                          6
# 48                            2             UNC                          2
# 49                            2          TRAUMA                          2
# 50                            6            SICK                          6
# 51                            2          STATEP                          2
#
#    FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 42    06/02/2020 02:39:24 PM                              Y
# 43    05/08/2020 12:02:34 AM                              Y
# 44    04/12/2020 09:20:33 PM                              Y
# 45    06/26/2020 10:59:54 PM                              Y
# 46    04/09/2020 08:29:30 AM                              Y
# 47    03/28/2020 01:23:56 AM                              Y
# 48    05/11/2020 11:40:43 PM                              Y
# 49    06/11/2020 04:18:34 PM                              Y
# 50    03/03/2020 02:35:16 AM                              Y
# 51    01/31/2020 10:36:21 PM                              Y
#
#     DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 42                             8    06/02/2020 02:39:43 PM  ...
# 43                            25    05/08/2020 12:02:55 AM  ...
# 44                           173    04/12/2020 09:20:33 PM  ...
# 45                             9    06/26/2020 11:00:01 PM  ...
# 46                             4    04/09/2020 08:29:55 AM  ...
# 47                            94    03/28/2020 01:24:07 AM  ...
# 48                            11    05/11/2020 11:40:48 PM  ...
# 49                            19    06/11/2020 04:19:07 PM  ...
# 50                            11    03/03/2020 02:35:46 AM  ...
# 51                            25    01/31/2020 10:36:32 PM  ...
#
#    POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 42           88.0                35.0              302.0
# 43           23.0                 8.0              111.0
# 44           75.0                37.0              305.0
# 45          114.0                22.0              401.0
# 46          122.0                50.0              502.0
# 47            5.0                 1.0              101.0
# 48           40.0                 8.0              201.0
# 49           67.0                40.0              317.0
# 50           79.0                36.0              303.0
# 51          114.0                26.0              401.0
#
#     COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 42                     13.0                   8.0                N
# 43                      4.0                  13.0                N
# 44                     19.0                   8.0                N
# 45                     30.0                  12.0                N
# 46                     31.0                  11.0                N
# 47                      2.0                   7.0                N
# 48                      7.0                  15.0                Y
# 49                     17.0                   9.0                N
# 50                     16.0                   8.0                N
# 51                     30.0                  12.0                N
#
#    SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 42                       N                 N                   N  chunk171.csv
# 43                       N                 N                   N  chunk170.csv
# 44                       N                 N                   N  chunk169.csv
# 45                       N                 N                   N  chunk172.csv
# 46                       N                 N                   N  chunk169.csv
# 47                       N                 N                   N  chunk168.csv
# 48                       N                 N                   N  chunk170.csv
# 49                       N                 N                   N  chunk171.csv
# 50                       N                 N                   N  chunk167.csv
# 51                       N                 N                   N  chunk166.csv
#
# [10 rows x 32 columns]

# %%
## store rows 42 through 51 inclusive into a df called df_excerpt

df_excerpt = ems2020_excerpt_df.loc[42:51]

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there

## HOMEWORK ANSWERS: 
## 1. overview below (vvv)
## 2. There are 32 columns in this dataframe, each of which holds its own type of data.\
##    4 of the columns in this dataset hold integers, 19 columns hold objects, and 9 columns hold floats
## 3. There are 32 columns and 13,117 rows in this dataframe.

ems2020_excerpt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13117 entries, 0 to 13116
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CAD_INCIDENT_ID                 13117 non-null  int64
#  1   INCIDENT_DATETIME               13117 non-null  object
#  2   INITIAL_CALL_TYPE               13117 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     13117 non-null  int64
#  4   FINAL_CALL_TYPE                 13117 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       13117 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       13010 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  13117 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    13117 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       12988 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         12533 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  13117 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    12533 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   12533 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          7870 non-null   object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     7791 non-null   object
#  16  INCIDENT_CLOSE_DATETIME         13110 non-null  object
#  17  HELD_INDICATOR                  13117 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       12985 non-null  float64
#  19  BOROUGH                         13117 non-null  object
#  20  INCIDENT_DISPATCH_AREA          13117 non-null  object
#  21  ZIPCODE                         12987 non-null  float64
#  22  POLICEPRECINCT                  12988 non-null  float64
#  23  CITYCOUNCILDISTRICT             12988 non-null  float64
#  24  COMMUNITYDISTRICT               12988 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         12978 non-null  float64
#  26  CONGRESSIONALDISTRICT           12988 non-null  float64
#  27  REOPEN_INDICATOR                13117 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         13117 non-null  object
#  29  STANDBY_INDICATOR               13117 non-null  object
#  30  TRANSFER_INDICATOR              13117 non-null  object
#  31  source                          13117 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 3.2+ MB

# %% [markdown]
# ## Targeting an Excel sheet
#
# We need the Customs and Border Protection data in this ```multi-data.xlsx``` workbook.

# %%
## import data here

cbp_data = pd.read_excel("multi-data.xlsx")

# %%
## call the top 15 rows

cbp_data.head(15)
# Out:
#     Serial Number      County License Type Code License Class Code  \
# 0         2000777      ALBANY                HL                242
# 1         1197749      NASSAU                CT                246
# 2         2149537    SULLIVAN                AX                122
# 3         1311950      QUEENS                 W                322
# 4         2217319      PUTNAM                TW                344
# 5         1319511    NEW YORK                RW                341
# 6         2220767  MONTGOMERY                 C                103
# 7         2129283      ALBANY                WS                308
# 8         2138381      ALBANY                WS                308
# 9         2160505      ALBANY                WS                308
# 10        2175892      ALBANY                WS                308
# 11        2188886      ALBANY                WS                308
# 12        2192454      ALBANY                WS                308
# 13        1286881    NEW YORK                OP                252
# 14        1289791       BRONX                AX                122
#
#     Certificate Number                   Premise Name                     DBA  \
# 0               912771          SUPER HOST HOTELS INC     ALBANY RAMADA PLAZA
# 1               913036          MEMORARE CATERERS INC                     NaN
# 2               910149              AHMED TRADING INC                     NaN
# 3               903719                    CAOTICO LLC             FORET WINES
# 4               917985           COFFEE TIME CAFE INC                     NaN
# 5               831035  DONATELLA MOXY 7TH AVENUE LLC         PROVA PIZZA BAR
# 6               935317              CUDA BEVERAGE LLC         BILL'S BEVERAGE
# 7               911084       SILVERADO VINEYARDS, THE                     NaN
# 8               911310          VOLCANO VINEYARDS LLC          VOLCANO WINERY
# 9               911278            J J COHN ESTATE LLC                     NaN
# 10              911215    KENEFICK RANCHES WINERY LLC   KENEFICK RANCH WINERY
# 11              909969                       KSSM LLC    MICHAEL SCHLUMBERGER
# 12              918967     TERRAVANT WINE COMPANY LLC  TERRAVANT WINE COMPANY
# 13              913420                 MERMAID 88 LLC         THE MERMAID INN
# 14              912566     NEW FORDHAM FOOD PLAZA INC                     NaN
#
#            Premise Address           Premise Address 2    Premise City  ...  \
# 0         3 WATERVLIET AVE                         NaN          ALBANY  ...
# 1       2183 JACKSON AVE A  WAVERLY AVE & MERRICK ROAD         SEAFORD  ...
# 2      1302 STATE ROUTE 52                         NaN  LOCH SHELDRAKE  ...
# 3         68-38 FOREST AVE                STOREFRONT C       RIDGEWOOD  ...
# 4               559 RTE 6N                         NaN         MAHOPAC  ...
# 5              485 7TH AVE                GROUND FLOOR        NEW YORK  ...
# 6              1 WILLOW ST                         NaN       AMSTERDAM  ...
# 7     6121 SILVERADO TRAIL                         NaN            NAPA  ...
# 8        35 PILMAUNA DRIVE                         NaN         VOLCANO  ...
# 9          5055 SOLANO AVE                  7079689367            NAPA  ...
# 10    4550 SILVERADO TRAIL                         NaN       CALISTOGA  ...
# 11      4155 WINE CREEK RD                         NaN      HEALDSBURG  ...
# 12  35 & 70 INDUSTRIAL WAY                         NaN        BUELLTON  ...
# 13   570-572 AMSTERDAM AVE                         NaN        NEW YORK  ...
# 14        2487 CRESTON AVE                         NaN           BRONX  ...
#
#    Premise Zip License Issued Date License Expiration Date  \
# 0        12206          2019-11-15              2021-11-30
# 1        11783          2019-11-22              2021-11-30
# 2        12759          2018-11-19              2021-11-30
# 3        11385          2018-12-31              2021-11-30
# 4        10541          2019-12-05              2021-11-30
# 5        10123          2019-12-23              2021-11-30
# 6        12010          2020-12-14              2021-11-30
# 7        94558          2018-12-03              2021-12-31
# 8        96785          2018-12-10              2021-12-31
# 9        94558          2018-12-10              2021-12-31
# 10   945159647          2018-12-07              2021-12-31
# 11       95448          2018-11-08              2021-12-31
# 12       93427          2019-06-17              2021-12-31
# 13       10024          2019-12-05              2021-12-31
# 14       10468          2019-01-10              2021-12-31
#
#                                   Method of Operation  \
# 0   HOTEL RESTAURANT SERVING BEER WINE CIDER AND L...
# 1          CATERER SERVING BEER CIDER WINE AND LIQUOR
# 2        GROCERY SELLING BEER CIDER AND WINE PRODUCTS
# 3                             WINE STORE SELLING WINE
# 4                        TAVERN SERVING BEER AND WINE
# 5             RESTAURANT SERVING WINE, BEER AND CIDER
# 6                                      WHOLESALE BEER
# 7                         OUT OF STATE DIRECT SHIPPER
# 8                         OUT OF STATE DIRECT SHIPPER
# 9                    OUT OF STATE DIRECT WINE SHIPPER
# 10                        OUT OF STATE DIRECT SHIPPER
# 11                                                NaN
# 12                                                NaN
# 13    RESTAURANT SERVING BEER, WINE, CIDER AND LIQUOR
# 14  GROCERY STORE SELLING BEER CIDER AND WINE PROD...
#
#         Days/Hours of Operation                                    Other  \
# 0                           NaN                                      NaN
# 1                           NaN                                      NaN
# 2                           NaN                                      NaN
# 3                           NaN                                      NaN
# 4                           NaN                                      NaN
# 5                           NaN  Recorded Music Permitted and No Dancing
# 6                           NaN                                      NaN
# 7                           NaN                                      NaN
# 8                           NaN                                      NaN
# 9                           NaN                                      NaN
# 10                          NaN                                      NaN
# 11                          NaN                                      NaN
# 12                          NaN                                      NaN
# 13  RECORDED MUSIC. NO DANCING.                  LICENSED SIDEWALK CAFE.
# 14                          NaN                                      NaN
#
#                              Georeference Zone  Effective Date Original Date
# 0            POINT (-73.783705 42.674761)    2      2019-12-01    1996-12-05
# 1            POINT (-73.487062 40.668214)    1      2019-12-01    2007-12-18
# 2             POINT (-74.66699 41.777859)    2      2018-12-01    2009-12-22
# 3             POINT (-73.90109 40.702673)    1      2018-12-31    2018-12-31
# 4            POINT (-73.763883 41.374319)    2      2019-12-05    2019-12-05
# 5                                     NaN    1      2019-12-23    2019-12-23
# 6              POINT (-74.1866 42.940987)    2      2020-12-14    2020-12-14
# 7    POINT (-122.33304899999999 38.40974)    2      2019-01-01    2005-10-19
# 8                                     NaN    2      2019-01-01    2007-06-28
# 9     POINT (-122.33301599999999 38.3548)    2      2019-01-01    2010-07-02
# 10   POINT (-122.54937700000002 38.57468)    2      2019-01-01    2011-08-11
# 11  POINT (-122.95010999999998 38.656503)    2      2019-01-01    2013-01-10
# 12          POINT (-120.202402 34.609092)    2      2019-06-17    2013-08-30
# 13            POINT (-73.97424 40.788753)    1      2020-01-01    2015-09-15
# 14           POINT (-73.898153 40.862681)    1      2019-01-10    2016-01-28
#
# [15 rows x 21 columns]
